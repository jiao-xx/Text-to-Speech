# %%
import requests
import os
import base64
from IPython.display import Audio, display
import ast

# pip install openai==0.27.0
import openai

openai.api_key = "key"

# %% [markdown]
# # Transcript Cleaning

# %%
# Let's read the uploaded file to understand its content and structure.
file_path = 'GENSUP04-P1.vtt'

with open(file_path, 'r', encoding='utf-8') as file:
    content = file.readlines()

content[:20]  # Display the first 20 lines to get an idea of the structure.
# Out:
# ['WEBVTT\n',
#  '\n',
#  '1\n',
#  '00:00:02.300 --> 00:00:08.590 \n',
#  'Hello, my name is Tomas, I am flight test\n',
#  'instrumentation engineer and instructor\n',
#  '\n',
#  '2\n',
#  '00:00:08.600 --> 00:00:10.210 \n',
#  'of ITPS.\n',
#  '\n',
#  '3\n',
#  '00:00:11.280 --> 00:00:13.490 \n',
#  'Today I am going to talk about\n',
#  '\n',
#  '4\n',
#  '00:00:13.500 --> 00:00:16.510 \n',
#  'introduction of flight test instrumentation.\n',
#  '\n',
#  '5\n']

# %%
# Function to clean and group VTT file content into paragraphs
def clean_and_group_vtt(file_lines):
    paragraphs = []
    current_paragraph = []

    for line in file_lines:
        line = line.strip()
        if line.isdigit() or "-->" in line:
            # Skip number lines and timestamp lines
            continue
        if not line:
            # If there's a blank line, start a new paragraph
            if current_paragraph:
                paragraphs.append(" ".join(current_paragraph))
                current_paragraph = []
        else:
            # Add non-blank lines to the current paragraph
            current_paragraph.append(line)

    # Add the last paragraph if there's remaining content
    if current_paragraph:
        paragraphs.append(" ".join(current_paragraph))

    return paragraphs

# Clean and group the content
paragraphs = clean_and_group_vtt(content)

# Exclude the "WEBVTT" line and ensure only meaningful paragraphs are included
paragraphs = [para for para in paragraphs if para.lower() != "webvtt"]


paragraphs[:5]
# Out:
# ['Hello, my name is Tomas, I am flight test instrumentation engineer and instructor',
#  'of ITPS.',
#  'Today I am going to talk about',
#  'introduction of flight test instrumentation.',
#  'So the main objectives of this lecture']

# %% [markdown]
# # LLM Slide Text Grouping

# %%
system_slide_grouping = "You are a highly skilled text processor and presentation designer. Your task is to analyze and group large text inputs into logical, speech-friendly sections for presentation slides and text-to-speech conversion. You excel at handling long documents efficiently."

context_slide_grouping = f"""
The task is to group a large input script into logical sections suitable for text-to-speech transcripts and presentation. The input script contains over 500 lines, and it is crucial to process the entire input without missing any details.

--------
Your Task:
1. Analyze and segment the input text:
    - Break the script into 30–50 logical slides.
    - Each slide should represent a single idea, subtopic, or group of closely related ideas that can be naturally spoken in **1–2 minutes**.
    - Summarize or paraphrase where appropriate, but do NOT omit critical details. Use transitions or additional context as needed for smoother delivery.

2. Optimize for text-to-speech tools:
    - Append **....** at logical pauses to guide pacing.
    - Use **CAPITAL LETTERS** to emphasize important words or phrases.

3. Maintain clarity and flow:
    - Ensure the text on each slide is **speech-friendly**, clear, and concise.
    - Write 2–8 sentences per slide, depending on the complexity of the content.
    - Keep the overall length under an hour while preserving all details.

4. Logical grouping and progression:
    - Begin with an introduction, followed by main sections, subtopics, and a conclusion.
    - Match the flow to common presentation structures: introduction, key ideas, examples, technical details, and summary.

5. Strict slide limit:
    - Ensure the total output is no more than 50 slides.
    - Avoid overly long slides by splitting dense content into multiple parts if needed.

--------
Return the processed content as a dictionary with the following format:
    "slide 1": "Introduction: content with pauses and emphasis here ....",
    "slide 2": "Main topic or subtopic: content with pauses and emphasis here ....",
    "slide 3": "Sub-details or examples: content with pauses and emphasis here ....",
    ...
    "slide 50": "Conclusion: content with pauses and emphasis here ...."
--------
Here is the input text to process:
{paragraphs}

"""


responses_slide_grouping = openai.ChatCompletion.create(
  model="gpt-4-turbo",  #gpt-4-turbo (expensive), gpt-3.5-turbo (cheap)
  messages=[
      {"role": "system", "content": system_slide_grouping},
      {"role": "user", "content": context_slide_grouping}
  ],
  temperature=0.1,
)

slide_content = responses_slide_grouping.choices[0].message.content
print(slide_content)
# Out:
# ```python
# {
#     "slide 1": "Introduction: Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....",
#     "slide 2": "Objectives: The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....",
#     "slide 3": "FTI Motivation: Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....",
#     "slide 4": "Instrumentation Overview: Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....",
#     "slide 5": "Metrology and Reliability: Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....",
#     "slide 6": "System Components: An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ....",
#     "slide 7": "Applications of Instrumentation: Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....",
#     "slide 8": "Unique Systems: Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....",
#     "slide 9": "Design Considerations: Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....",
#     "slide 10": "Generic System Components: Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....",
#     "slide 11": "Data Recording and Transmission: The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....",
#     "slide 12": "Ground Stations: The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....",
#     "slide 13": "System Requirements: Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....",
#     "slide 14": "Measurement Points: Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....",
#     "slide 15": "Design Questions: Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....",
#     "slide 16": "Data Types and Requirements: Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....",
#     "slide 17": "Transducers and Sensors: Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....",
#     "slide 18": "Analysis Tools: The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....",
#     "slide 19": "Existing Instrumentation: Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....",
#     "slide 20": "Post-Flight Analysis Facilities: The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....",
#     "slide 21": "Power and Weight Considerations: Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ....",
#     "slide 22": "From Concept to Design: Transitioning from the conceptual understanding of FTI to practical design considerations, focusing on creating effective measurement chains for each parameter ....",
#     "slide 23": "Measurement Chain Concept: Exploring the three steps of the measurement chain—signal source, data acquisition, and data analysis—to ensure comprehensive data collection and analysis ....",
#     "slide 24": "Transducer Quality: Emphasizing the importance of transducer quality in determining data reliability, and discussing various types of transducers used in FTI systems ....",
#     "slide 25": "Transducer Characteristics: Detailed discussion on important transducer characteristics like range, sensitivity, accuracy, and response time, which influence their selection and performance ....",
#     "slide 26": "Data Acquisition Techniques: The evolution of data acquisition techniques, from multiplexing to modern methods that allow for the simultaneous recording of multiple parameters ....",
#     "slide 27": "FTI Hardware Evolution: Tracing the development of FTI hardware from manual recording methods to advanced digital systems that enhance data collection and analysis capabilities ....",
#     "slide 28": "Recorder Technology: The progression from analog recorders to modern digital systems that offer higher storage capacities and faster data processing ....",
#     "slide 29": "Special FTI Systems - Telemetry: Discussing the specific role and design of telemetry systems in FTI, which provide real-time data to ground engineers during flight tests ....",
#     "slide 30": "Video Systems in FTI: The use of video systems to visually document test conditions, which is crucial for analyzing aspects of the aircraft that are not captured by traditional sensors ....",
#     "slide 31": "Trailing Cone Systems: Exploring the design and function of trailing cone systems, which measure static pressure in conditions free from aerodynamic interference ....",
#     "slide 32": "Pressure Scanners: Detailed look at pressure scanners, which are high-accuracy transducers used for performance testing, featuring internal calibration for precise measurements ....",
#     "slide 33": "Icing Probe Systems: The role and design of icing probe systems in collecting data on ice accumulation during flight, which is critical for safety and performance assessments ....",
#     "slide 34": "Conclusion: Thank you for your attention during this detailed exploration of Flight Test Instrumentation. For any questions, please contact ITPS. Have a great day ...."
# }
# ```

# %% [markdown]
# ## Organize output

# %%
slide_content
# Out:
# '```python\n{\n    "slide 1": "Introduction: Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....",\n    "slide 2": "Objectives: The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....",\n    "slide 3": "FTI Motivation: Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....",\n    "slide 4": "Instrumentation Overview: Instrumentation involves technology for measurement and control. In flight tests, it\'s used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....",\n    "slide 5": "Metrology and Reliability: Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....",\n    "slide 6": "System Components: An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft\'s performance ....",\n    "slide 7": "Applications of Instrumentation: Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....",\n    "slide 8": "Unique Systems: Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....",\n    "slide 9": "Design Considerations: Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....",\n    "slide 10": "Generic System Components: Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....",\n    "slide 11": "Data Recording and Transmission: The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....",\n    "slide 12": "Ground Stations: The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....",\n    "slide 13": "System Requirements: Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....",\n    "slide 14": "Measurement Points: Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....",\n    "slide 15": "Design Questions: Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....",\n    "slide 16": "Data Types and Requirements: Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....",\n    "slide 17": "Transducers and Sensors: Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....",\n    "slide 18": "Analysis Tools: The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....",\n    "slide 19": "Existing Instrumentation: Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....",\n    "slide 20": "Post-Flight Analysis Facilities: The infrastructure needed for effective data analysis post-flight, ...

# %%
# Remove Python declaration and convert to dictionary
# Extract the part inside `{}` and convert to dictionary
content_start = slide_content.find("{")
content_end = slide_content.rfind("}") + 1
slide_content_dict = ast.literal_eval(slide_content[content_start:content_end])

# Verify the output
for key, value in slide_content_dict.items():
    print(f"{key}: {value}")
# Out:
# slide 1: Introduction: Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....
# slide 2: Objectives: The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....
# slide 3: FTI Motivation: Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....
# slide 4: Instrumentation Overview: Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....
# slide 5: Metrology and Reliability: Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....
# slide 6: System Components: An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ....
# slide 7: Applications of Instrumentation: Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....
# slide 8: Unique Systems: Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....
# slide 9: Design Considerations: Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....
# slide 10: Generic System Components: Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....
# slide 11: Data Recording and Transmission: The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....
# slide 12: Ground Stations: The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....
# slide 13: System Requirements: Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....
# slide 14: Measurement Points: Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....
# slide 15: Design Questions: Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....
# slide 16: Data Types and Requirements: Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....
# slide 17: Transducers and Sensors: Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....
# slide 18: Analysis Tools: The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....
# slide 19: Existing Instrumentation: Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....
# slide 20: Post-Flight Analysis Facilities: The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....
# slide 21: Power and Weight Considerations: Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ....
# slide 22: From Concept to Design: Transitioning from the conceptual understanding of FTI to practical design considerations, focusing on creating effective measurement chains for each parameter ....
# slide 23: Measurement Chain Concept: Exploring the three steps of the measurement chain—signal source, data acquisition, and data analysis—to ensure comprehensive data collection and analysis ....
# slide 24: Transducer Quality: Emphasizing the importance of transducer quality in determining data reliability, and discussing various types of transducers used in FTI systems ....
# slide 25: Transducer Characteristics: Detailed discussion on important transducer characteristics like range, sensitivity, accuracy, and response time, which influence their selection and performance ....
# slide 26: Data Acquisition Techniques: The evolution of data acquisition techniques, from multiplexing to modern methods that allow for the simultaneous recording of multiple parameters ....
# slide 27: FTI Hardware Evolution: Tracing the development of FTI hardware from manual recording methods to advanced digital systems that enhance data collection and analysis capabilities ....
# slide 28: Recorder Technology: The progression from analog recorders to modern digital systems that offer higher storage capacities and faster data processing ....
# slide 29: Special FTI Systems - Telemetry: Discussing the specific role and design of telemetry systems in FTI, which provide real-time data to ground engineers during flight tests ....
# slide 30: Video Systems in FTI: The use of video systems to visually document test conditions, which is crucial for analyzing aspects of the aircraft that are not captured by traditional sensors ....
# slide 31: Trailing Cone Systems: Exploring the design and function of trailing cone systems, which measure static pressure in conditions free from aerodynamic interference ....
# slide 32: Pressure Scanners: Detailed look at pressure scanners, which are high-accuracy transducers used for performance testing, featuring internal calibration for precise measurements ....
# slide 33: Icing Probe Systems: The role and design of icing probe systems in collecting data on ice accumulation during flight, which is critical for safety and performance assessments ....
# slide 34: Conclusion: Thank you for your attention during this detailed exploration of Flight Test Instrumentation. For any questions, please contact ITPS. Have a great day ....

# %%
slide_content_dict.values()
# Out:
# dict_values(['Introduction: Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....', 'Objectives: The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....', 'FTI Motivation: Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....', "Instrumentation Overview: Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....", 'Metrology and Reliability: Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....', "System Components: An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ....", 'Applications of Instrumentation: Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....', 'Unique Systems: Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....', 'Design Considerations: Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....', 'Generic System Components: Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....', 'Data Recording and Transmission: The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....', 'Ground Stations: The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....', 'System Requirements: Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....', 'Measurement Points: Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....', 'Design Questions: Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....', 'Data Types and Requirements: Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....', 'Transducers and Sensors: Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....', 'Analysis Tools: The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....', 'Existing Instrumentation: Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....', 'Post-Flight Analysis Facilities: The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....', "Power and Weight Considerations: Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ....", 'From Concept to Design: Transitioning from the conceptual understanding of FTI to practical design considerations,  ...

# %%
# Process to keep the title and content separately
processed_content = {}
for idx, text in enumerate(slide_content_dict.values(), 1):
    if ": " in text:
        title, content = text.split(": ", 1)  # Split into title and content
    else:
        title, content = f"Slide {idx}", text  # Default title if no colon exists
    processed_content[f"slide {idx}"] = {"title": title, "content": content}

# Print the processed dictionary
for slide, details in processed_content.items():
    print(f"{slide}: Title: {details['title']} | Content: {details['content']}")
# Out:
# slide 1: Title: Introduction | Content: Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....
# slide 2: Title: Objectives | Content: The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....
# slide 3: Title: FTI Motivation | Content: Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....
# slide 4: Title: Instrumentation Overview | Content: Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....
# slide 5: Title: Metrology and Reliability | Content: Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....
# slide 6: Title: System Components | Content: An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ....
# slide 7: Title: Applications of Instrumentation | Content: Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....
# slide 8: Title: Unique Systems | Content: Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....
# slide 9: Title: Design Considerations | Content: Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....
# slide 10: Title: Generic System Components | Content: Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....
# slide 11: Title: Data Recording and Transmission | Content: The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....
# slide 12: Title: Ground Stations | Content: The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....
# slide 13: Title: System Requirements | Content: Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....
# slide 14: Title: Measurement Points | Content: Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....
# slide 15: Title: Design Questions | Content: Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....
# slide 16: Title: Data Types and Requirements | Content: Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....
# slide 17: Title: Transducers and Sensors | Content: Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....
# slide 18: Title: Analysis Tools | Content: The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....
# slide 19: Title: Existing Instrumentation | Content: Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....
# slide 20: Title: Post-Flight Analysis Facilities | Content: The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....
# slide 21: Title: Power and Weight Considerations | Content: Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ....
# slide 22: Title: From Concept to Design | Content: Transitioning from the conceptual understanding of FTI to practical design considerations, focusing on creating effective measurement chains for each parameter ....
# slide 23: Title: Measurement Chain Concept | Content: Exploring the three steps of the measurement chain—signal source, data acquisition, and data analysis—to ensure comprehensive data collection and analysis ....
# slide 24: Title: Transducer Quality | Content: Emphasizing the importance of transducer quality in determining data reliability, and discussing various types of transducers used in FTI systems ....
# slide 25: Title: Transducer Characteristics | Content: Detailed discussion on important transducer characteristics like range, sensitivity, accuracy, and response time, which influence their selection and performance ....
# slide 26: Title: Data Acquisition Techniques | Content: The evolution of data acquisition techniques, from multiplexing to modern methods that allow for the simultaneous recording of multiple parameters ....
# slide 27: Title: FTI Hardware Evolution | Content: Tracing the development of FTI hardware from manual recording methods to advanced digital systems that enhance data collection and analysis capabilities ....
# slide 28: Title: Recorder Technology | Content: The progression from analog recorders to modern digital systems that offer higher storage capacities and faster data processing ....
# slide 29: Title: Special FTI Systems - Telemetry | Content: Discussing the specific role and design of telemetry systems in FTI, which provide real-time data to ground engineers during flight tests ....
# slide 30: Title: Video Systems in FTI | Content: The use of video systems to visually document test conditions, which is crucial for analyzing aspects of the aircraft that are not captured by traditional sensors ....
# slide 31: Title: Trailing Cone Systems | Content: Exploring the design and function of trailing cone systems, which measure static pressure in conditions free from aerodynamic interference ....
# slide 32: Title: Pressure Scanners | Content: Detailed look at pressure scanners, which are high-accuracy transducers used for performance testing, featuring internal calibration for precise measurements ....
# slide 33: Title: Icing Probe Systems | Content: The role and design of icing probe systems in collecting data on ice accumulation during flight, which is critical for safety and performance assessments ....
# slide 34: Title: Conclusion | Content: Thank you for your attention during this detailed exploration of Flight Test Instrumentation. For any questions, please contact ITPS. Have a great day ....

# %%
# Extract just the content
slide_contents = [details["content"] for details in processed_content.values()]
slide_contents
# Out:
# ['Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....',
#  'The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....',
#  'Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....',
#  "Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ....",
#  'Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....',
#  "An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ....",
#  'Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....',
#  'Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....',
#  'Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....',
#  'Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....',
#  'The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....',
#  'The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....',
#  'Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....',
#  'Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....',
#  'Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....',
#  'Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....',
#  'Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....',
#  'The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....',
#  'Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....',
#  'The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....',
#  "Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ....",
#  'Transitioning from the conceptual understanding of FTI to practical design considerations, focusing on creating effective measurement chains for each parameter ....',
#  'Exploring the three steps of the measurement chain—signal source, data acquisition, and data analysis—to ensure comprehensive data collection and analysis ....',
#  'Emphasizing the importance of transducer quality in determining data reliability, and discussing various types of transducers used in FTI systems ....',
#  'Detailed discussion on important transducer characteristics like range, sensitivity, accuracy, and response time, which influence their selection and performance ....',
#  'The evolution of data acquisition techniques, from multiplexing to modern methods that allow for the simultaneous recording of multiple parameters ....',
#  'Tracing the development of FTI hardware from manual recording methods to advanced digital systems that enhance data collection and analysis capabilities ....',
#  'The progression from analog recorders to modern digital systems that offer higher storage capacities and faster data processing ....',
#  'Discussing the specific role and design of telemetry systems in FTI, which provide real-time data to ground engineers during flight tests ....',
#  'The use of video systems to visually document test conditions, which is crucial for analyzing aspects of the aircraft that are not captured by traditional sensors ....',
#  'Exploring the design and function of trailing cone systems, which measure static pressure in conditions free from aerodynamic interference ....',
#  'Detailed look at pressure scanners, which are high-accuracy transducers used for performance testing, featuring internal calibration for precise measurements ....',
#  'The role and design of icing probe systems in collecting data on ice accumulation during flight, which is critical for safety and performance assessments ....',
#  'Thank you for your attention during this detailed exploration of Flight Test Instrumentation. For any questions, please contact ITPS. Have a great day ....']

# %% [markdown]
# # LLM Powerpoint Bullet Points

# %%
processed_content
# Out:
# {'slide 1': {'title': 'Introduction',
#   'content': 'Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at ITPS. Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....'},
#  'slide 2': {'title': 'Objectives',
#   'content': 'The main objectives of this lecture are to provide an overview of Flight Test Instrumentation (FTI) as an airborne system, summarize its functions, and discuss its components like signal sources, transducers, and data acquisition systems ....'},
#  'slide 3': {'title': 'FTI Motivation',
#   'content': 'Why do we use instrumentation in prototype aircraft? Imagine the early days of aviation, where engineers and pilots had limited means to gather flight data. The need for detailed and reliable data is what drives the use of FTI ....'},
#  'slide 4': {'title': 'Instrumentation Overview',
#   'content': "Instrumentation involves technology for measurement and control. In flight tests, it's used to monitor measurement points on the aircraft, providing crucial data without controlling other systems ...."},
#  'slide 5': {'title': 'Metrology and Reliability',
#   'content': 'Good instrumentation adheres to metrology standards to ensure reliable data, which is essential for evaluating aircraft prototypes ....'},
#  'slide 6': {'title': 'System Components',
#   'content': "An FTI system includes necessary hardware and software to gather and analyze data, helping system engineers assess the aircraft's performance ...."},
#  'slide 7': {'title': 'Applications of Instrumentation',
#   'content': 'Beyond aviation, instrumentation is vital in fields like car manufacturing, space missions, and environmental monitoring, demonstrating its wide-ranging utility ....'},
#  'slide 8': {'title': 'Unique Systems',
#   'content': 'Each aircraft may have a specialized instrumentation system designed to meet specific test conditions, highlighting the bespoke nature of these systems ....'},
#  'slide 9': {'title': 'Design Considerations',
#   'content': 'Designing an FTI system involves understanding the specific requirements and constraints, including cost and system integration ....'},
#  'slide 10': {'title': 'Generic System Components',
#   'content': 'Discussing components like signal sources, conditioners, and data acquisition systems that collectively process and record flight data ....'},
#  'slide 11': {'title': 'Data Recording and Transmission',
#   'content': 'The importance of recording flight data for post-flight analysis and using transmitters for real-time data transmission during flight tests for safety and decision-making ....'},
#  'slide 12': {'title': 'Ground Stations',
#   'content': 'The role of ground stations in receiving, demodulating, and analyzing flight data, which is crucial for real-time and post-flight analysis ....'},
#  'slide 13': {'title': 'System Requirements',
#   'content': 'Exploring where requirements for FTI systems originate, including documentation and system engineer inputs that dictate measurement specifics ....'},
#  'slide 14': {'title': 'Measurement Points',
#   'content': 'Understanding the variety and source of measurement points, which can range from digital data buses to physical sensors, each contributing to the comprehensive data collection ....'},
#  'slide 15': {'title': 'Design Questions',
#   'content': 'Key questions that influence FTI system design, such as the purpose of the system, the data source, and the intended permanence of the installation ....'},
#  'slide 16': {'title': 'Data Types and Requirements',
#   'content': 'Discussing the need for both quantitative and qualitative data, the required accuracy, and how these factors influence system design ....'},
#  'slide 17': {'title': 'Transducers and Sensors',
#   'content': 'Choosing appropriate sensors based on required accuracy and sample rates, which are critical for capturing precise data during tests ....'},
#  'slide 18': {'title': 'Analysis Tools',
#   'content': 'The necessity of providing robust software tools for data analysis, ensuring that system engineers can effectively evaluate test results ....'},
#  'slide 19': {'title': 'Existing Instrumentation',
#   'content': 'Considering the existing instrumentation on an aircraft and whether it can support additional measurements or needs a complete overhaul ....'},
#  'slide 20': {'title': 'Post-Flight Analysis Facilities',
#   'content': 'The infrastructure needed for effective data analysis post-flight, including hardware and software tools ....'},
#  'slide 21': {'title': 'Power and Weight Considerations',
#   'content': "Assessing the power requirements and weight of the instrumentation system to ensure compatibility with the aircraft's capabilities ...."},
#  'slide 22': {'title': 'From Concept to Design',
#   'content': 'Transitioning from the conceptual understanding of FTI to practical design considerations, focusing on creating effective measurement chains for each parameter ....'},
#  'slide 23': {'title': 'Measurement Chain Concept',
#   'content': 'Exploring the three steps of the measurement chain—signal source, data acquisition, and data analysis—to ensure comprehensive data collection and analysis ....'},
#  'slide 24': {'title': 'Transducer Quality',
#   'content': 'Emphasizing the importance of transducer quality in determining data reliability, and discussing various types of transducers used in FTI systems ....'},
#  'slide 25': {'title': 'Transducer Characteristics',
#   'content': 'Detailed discussion on important transducer characteristics like range, sensitivity, accuracy, and response time, which influence their selection and performance ....'},
#  'slide 26': {'title': 'Data Acquisition Techniques',
#   'content': 'The evolution of data acquisition techniques, from multiplexing to modern methods that allow for the simultaneous recording of multiple parameters ....'},
#  'slide 27': {'title': 'FTI Hardware Evolution',
#   'content': 'Tracing the development of FTI hardware from manual recording methods to advanced digital systems that enhance data collection and analysis capabilities ....'},
#  'slide 28': {'title': 'Recorder Technology',
#   'content': 'The progression from analog recorders to modern digital systems that offer higher storage capacities and faster data processing ....'},
#  'slide 29': {'title': 'Special FTI Systems - Telemetry',
#   'content': 'Discussing the specific role and design of telemetry systems in FTI, which provide real-time data to ground engineers during flight tests ....'},
#  'slide 30': {'title': 'Video Systems in FTI',
#   'content': 'The use of video systems to visually document test conditions, which is crucial for analyzing aspects of the aircraft that are not captured by traditional sensors ....'},
#  'slide 31': {'title': 'Trailing Cone Systems',
#   'content': 'Exploring the design and function of trailing cone systems, which measure static pressure in conditions free from aerodynamic interference ....'},
#  'slide 32': {'title': 'Pressure Scanners',
#   'content': 'Detailed look at pressure scanners, which are high-accuracy transducers used for performance testing, featuring internal calibration for precise measurements ....'},
#  'slide 33': {'title': 'Icing Probe Systems',
#   'content': 'The role and design of icing probe systems in collecting data on ice accumulation during flight, which is critical for safety and performance assessments ....'},
#  'slide 34': {'title': 'Conclusion',
#   'content': 'Thank you for your attention during this detailed exploration of Flight Test Instrumentation. For any questions, please contact ITPS. Have a great day ....'}}

# %%
system_slide_grouping = """
You are a highly skilled text processor and presentation designer. 
Your task is to take slide data with titles and content in a structured format, 
You excel at organizing text clearly and concisely while maintaining logical flow and essential details.
"""

context_slide_grouping = f"""
The task is to broken down the input into bullet points for each PowerPoint slide.
Each slide should include:
1. Slide Title: Begin with the title (e.g., 'Slide 1: Introduction').
2. Content: Rewrite the slide's content as concise bullet points in the output. Ensure:
    - Each idea is presented on a new line.
    - Important concepts or terms are capitalized for emphasis.
    - Logical grouping of related ideas within each slide.

3. Output Format: Return the result as text, formatted like this:
    ```
    Slide 1: Title
    point 1.
    point 2.
    point 3.
    
    Slide 2: Title
    point 1.
    point 2.
    point 3.
    ```

Here is the input data to process:
{processed_content}
"""

responses_slide_grouping = openai.ChatCompletion.create(
  model="gpt-4-turbo",  # Switch between gpt-4-turbo and gpt-3.5-turbo as needed
  messages=[
      {"role": "system", "content": system_slide_grouping},
      {"role": "user", "content": context_slide_grouping}
  ],
  temperature=0.1,
)

slide_bulletpoints = responses_slide_grouping.choices[0].message.content
print(slide_bulletpoints)
# Out:
# ```
# Slide 1: Introduction
# - Hello, my name is Tomas.
# - I am a Flight Test Instrumentation Engineer and Instructor at ITPS.
# - Today's topic: FLIGHT TEST INSTRUMENTATION.
#
# Slide 2: Objectives
# - Provide an OVERVIEW of Flight Test Instrumentation (FTI) as an airborne system.
# - Summarize FTI FUNCTIONS.
# - Discuss FTI COMPONENTS: signal sources, transducers, data acquisition systems.
#
# Slide 3: FTI Motivation
# - Importance of INSTRUMENTATION in prototype aircraft.
# - Historical context: Limited data gathering in early aviation.
# - Need for DETAILED and RELIABLE data drives FTI use.
#
# Slide 4: Instrumentation Overview
# - Instrumentation involves MEASUREMENT and CONTROL technology.
# - Used in flight tests to MONITOR measurement points on aircraft.
# - Provides CRUCIAL DATA without controlling other systems.
#
# Slide 5: Metrology and Reliability
# - Instrumentation adheres to METROLOGY STANDARDS.
# - Ensures RELIABLE DATA for evaluating aircraft prototypes.
#
# Slide 6: System Components
# - FTI system includes necessary HARDWARE and SOFTWARE.
# - Helps engineers ASSESS aircraft performance.
#
# Slide 7: Applications of Instrumentation
# - Instrumentation's utility in AVIATION, car manufacturing, space missions, and environmental monitoring.
# - Demonstrates WIDE-RANGING UTILITY.
#
# Slide 8: Unique Systems
# - Each aircraft may have SPECIALIZED instrumentation systems.
# - Designed to meet SPECIFIC test conditions.
#
# Slide 9: Design Considerations
# - Designing an FTI system requires understanding SPECIFIC REQUIREMENTS and constraints.
# - Considerations include COST and SYSTEM INTEGRATION.
#
# Slide 10: Generic System Components
# - Discussing components like SIGNAL SOURCES, conditioners, and data acquisition systems.
# - These components PROCESS and RECORD flight data.
#
# Slide 11: Data Recording and Transmission
# - Importance of RECORDING flight data for post-flight analysis.
# - Use of TRANSMITTERS for real-time data transmission during flight tests.
#
# Slide 12: Ground Stations
# - Role of ground stations in RECEIVING, demodulating, and analyzing flight data.
# - Crucial for REAL-TIME and POST-FLIGHT analysis.
#
# Slide 13: System Requirements
# - Exploring ORIGINS of requirements for FTI systems.
# - Includes DOCUMENTATION and system engineer INPUTS.
#
# Slide 14: Measurement Points
# - Variety and SOURCE of measurement points.
# - Includes digital data buses and PHYSICAL SENSORS.
#
# Slide 15: Design Questions
# - Key questions influencing FTI system design.
# - Consider PURPOSE of the system, DATA SOURCE, and installation PERMANENCE.
#
# Slide 16: Data Types and Requirements
# - Need for QUANTITATIVE and QUALITATIVE data.
# - Required ACCURACY influences system design.
#
# Slide 17: Transducers and Sensors
# - Choosing sensors based on REQUIRED ACCURACY and sample rates.
# - Critical for capturing PRECISE DATA during tests.
#
# Slide 18: Analysis Tools
# - Necessity of robust SOFTWARE TOOLS for data analysis.
# - Enables effective evaluation of test results.
#
# Slide 19: Existing Instrumentation
# - Considering existing instrumentation on aircraft.
# - Assess if it supports additional measurements or needs OVERHAUL.
#
# Slide 20: Post-Flight Analysis Facilities
# - Infrastructure needed for EFFECTIVE DATA ANALYSIS post-flight.
# - Includes hardware and software tools.
#
# Slide 21: Power and Weight Considerations
# - Assessing POWER REQUIREMENTS and WEIGHT of the instrumentation system.
# - Ensure compatibility with aircraft's capabilities.
#
# Slide 22: From Concept to Design
# - Transitioning from CONCEPTUAL understanding to PRACTICAL design considerations.
# - Focus on creating effective MEASUREMENT CHAINS for each parameter.
#
# Slide 23: Measurement Chain Concept
# - Exploring three steps of the measurement chain: SIGNAL SOURCE, data acquisition, and data analysis.
# - Ensures COMPREHENSIVE data collection and analysis.
#
# Slide 24: Transducer Quality
# - Importance of TRANSDUCER QUALITY in determining data reliability.
# - Discuss various types of transducers in FTI systems.
#
# Slide 25: Transducer Characteristics
# - Discussing important characteristics: RANGE, sensitivity, ACCURACY, and response time.
# - Influences SELECTION and PERFORMANCE of transducers.
#
# Slide 26: Data Acquisition Techniques
# - Evolution of data acquisition techniques.
# - From MULTIPLEXING to modern methods for simultaneous recording of multiple parameters.
#
# Slide 27: FTI Hardware Evolution
# - Development of FTI hardware from MANUAL recording to advanced digital systems.
# - Enhances data COLLECTION and ANALYSIS capabilities.
#
# Slide 28: Recorder Technology
# - Progression from ANALOG recorders to modern digital systems.
# - Offers higher STORAGE capacities and faster data processing.
#
# Slide 29: Special FTI Systems - Telemetry
# - Specific role and design of TELEMETRY systems in FTI.
# - Provides REAL-TIME data to ground engineers during flight tests.
#
# Slide 30: Video Systems in FTI
# - Use of VIDEO SYSTEMS to document test conditions visually.
# - Crucial for analyzing aspects not captured by traditional sensors.
#
# Slide 31: Trailing Cone Systems
# - Design and function of trailing cone systems.
# - Measures STATIC PRESSURE in conditions free from aerodynamic interference.
#
# Slide 32: Pressure Scanners
# - Detailed look at PRESSURE SCANNERS, high-accuracy transducers for performance testing.
# - Features INTERNAL CALIBRATION for precise measurements.
#
# Slide 33: Icing Probe Systems
# - Role and design of icing probe systems.
# - Collects data on ICE ACCUMULATION during flight, critical for safety and performance.
#
# Slide 34: Conclusion
# - Thank you for your attention during this exploration of Flight Test Instrumentation.
# - For questions, please contact ITPS.
# - Have a great day.
# ```

# %% [markdown]
# # Text to Speech

# %%
test='''
Hello, my name is Tomas, I am a flight test instrumentation engineer and instructor at XXX. 
Today, I will introduce the topic of FLIGHT TEST INSTRUMENTATION ....
'''

# %%
API_KEY = 'Key'
API_URL = 'https://api.sws.speechify.com/v1/audio/speech'

headers = {
    'Authorization': f'Bearer {API_KEY}',
    'Content-Type': 'application/json'
}

data = {
    'input': test,
    'voice_id': 'henry',  # Replace with desired voice ID
    'audio_format': 'mp3',
    "options": {
    "loudness_normalization": True,
    'pitch': '+2st',                 # Adjust pitch (e.g., +2 semitones)
    'rate': 'medium',                # Adjust speed (e.g., 'medium', 'fast')
    'emotion': 'cheerful',
    },
     "model": "simba-english"
}


response = requests.post(API_URL, headers=headers, json=data)

# %%
response_data = response.json()

# Decode the base64 audio data
audio_data_base64 = response_data['audio_data']
decoded_audio_data = base64.b64decode(audio_data_base64)

# Save the audio to a file (optional)
with open("output.mp3", "wb") as audio_file:
    audio_file.write(decoded_audio_data)

# Play the audio in the notebook
display(Audio(decoded_audio_data, rate=44100, autoplay=True))

# %%
print(response.status_code)  # Check if it's 200
print(response.text)         # Check the raw response content
